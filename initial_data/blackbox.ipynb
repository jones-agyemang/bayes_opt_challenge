# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

from plotting_utils import (
    plot_2d_function
)

## Notes
# What do these functions look like? 
# Understand the functions and then start exploiting? 
# For some functions I may never reach a real minimum
# understanding core mML is more essential now
# a human reviewer needs to be in a loop
# Evaluation and development
# Reach out to support for help


load_input = lambda x, type: np.load(f'./function_{x}/initial_{type}.npy')

infunc1 = load_input(1, 'inputs')
outfunc1 = load_input(1, 'outputs')

## Plot 2-D Functions
f1x1 = infunc1[:, 0]
f1x2 = infunc1[:, 1]
f1z  = outfunc1
# plot_2d_function(f1x1, f1x2, f1z)




# Create a 3D scatter plot
# fig = plt.figure(figsize=(10, 7))
# ax = fig.add_subplot(111, projection='3d')

# # Plot each point: x-coord, y-coord, output value
# ax.scatter(infunc1[:, 0], infunc1[:, 1], outfunc1, c='blue', marker='o', s=100)

# ax.set_xlabel('Input X1')
# ax.set_ylabel('Input X2')
# ax.set_zlabel('Output')
# ax.set_title('Blackbox Function: 2D Inputs → 1D Output')

# plt.tight_layout()
# plt.show()

# # Alternative: 2D heatmap (if you want a cleaner view)
# fig, ax = plt.subplots(figsize=(8, 6))
# scatter = ax.scatter(infunc1[:, 0], infunc1[:, 1], c=outfunc1, cmap='viridis', s=200, alpha=0.6)
# ax.set_xlabel('Input X1')
# ax.set_ylabel('Input X2')
# ax.set_title('Blackbox Function Outputs (color intensity)')
# plt.colorbar(scatter, ax=ax, label='Output Value')
# plt.tight_layout()
# plt.show()

# infunc2 = load_input(2, 'inputs')
# outfunc2 = load_input(2, 'outputs')
# 
# infunc3 = load_input(3, 'inputs')
# outfunc3 = load_input(3, 'outputs')
# 
# infunc4 = load_input(4, 'inputs')
# outfunc4 = load_input(4, 'outputs')
# 
# infunc5 = load_input(5, 'inputs')
# outfunc5 = load_input(5, 'outputs')
# 
# infunc6 = load_input(6, 'inputs')
# outfunc6 = load_input(6, 'outputs')
# 
# infunc7 = load_input(7, 'inputs')
# outfunc7 = load_input(7, 'outputs')
# 
# infunc8 = load_input(8, 'inputs')
# outfunc8 = load_input(8, 'outputs')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 28
#      26 f1x2 = infunc1[:, 1]
#      27 f1z  = outfunc1
# ---> 28 plot_2d_function(f1x1, f1x2, f1z)
#      32 # Create a 3D scatter plot
#      33 # fig = plt.figure(figsize=(10, 7))
#      34 # ax = fig.add_subplot(111, projection='3d')
#    (...)     75 # infunc8 = load_input(8, 'inputs')
#      76 # outfunc8 = load_input(8, 'outputs')
#
# File ~/Projects/Imperial ML_AL/Mod-12/initial_data/plotting_utils.py:129, in plot_2d_function(X1, X2, Z, title)
#     118 """
#     119 Plot a 2D function as a contour plot.
#     120
#    (...)    125 title : str, plot title
#     126 """
#     127 fig, ax = plt.subplots(figsize=(10, 4))
# --> 129 contour = ax.contourf(X1, X2, Z, levels=20, cmap='viridis')
#     130 plt.colorbar(contour, ax=ax)
#     131 ax.set_xlabel('x1', fontsize=12)
#
# ...
